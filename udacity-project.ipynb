# %%
from azureml.core import Workspace, Experiment

ws = Workspace.get(name="quick-starts-ws-123371")
exp = Experiment(workspace=ws, name="udacity-project")

print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep = '\n')

run = exp.start_logging()
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code RA4HP7HMT to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
# Workspace name: quick-starts-ws-123371
# Azure region: southcentralus
# Subscription id: de8aba62-c352-42be-b980-2faedf08ead8
# Resource group: aml-quickstarts-123371

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# TODO: Create compute cluster
# Use vm_size = "Standard_D2_V2" in your provisioning configuration.
# max_nodes should be no greater than 4.

cpu_cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    cpu_cluster = ComputeTarget(workspace=ws, name=cpu_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',
                                                            max_nodes=4)
    cpu_cluster = ComputeTarget.create(ws, cpu_cluster_name, compute_config)

cpu_cluster.wait_for_completion(show_output=True)
# Out:
# Creating
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
from azureml.widgets import RunDetails
from azureml.train.sklearn import SKLearn
from azureml.train.hyperdrive.run import PrimaryMetricGoal
from azureml.train.hyperdrive.policy import BanditPolicy
from azureml.train.hyperdrive.sampling import RandomParameterSampling
from azureml.train.hyperdrive.runconfig import HyperDriveConfig
from azureml.train.hyperdrive.parameter_expressions import uniform
from azureml.train.hyperdrive.parameter_expressions import choice
import os

# Specify parameter sampler
ps = RandomParameterSampling({
    "C": uniform(0.001,100),
    "max_iter": choice(1,10,100,1000,10000)
})

# Specify a Policy
policy = BanditPolicy(slack_amount=0.2)

if "training" not in os.listdir():
    os.mkdir("./training")

# Create a SKLearn estimator for use with train.py
est = SKLearn(source_directory="training", 
                entry_script="train.py", 
                compute_target=cpu_cluster)

# Create a HyperDriveConfig using the estimator, hyperparameter sampler, and policy.
hyperdrive_config = HyperDriveConfig(ps,
                                    primary_metric_name="Accuracy", 
                                    primary_metric_goal=PrimaryMetricGoal.MAXIMIZE,
                                    max_total_runs=50,
                                    estimator=est,
                                    policy=policy)

# %%
# Submit your hyperdrive run to the experiment and show run details with the widget.
hyperdrive_run = exp.submit(hyperdrive_config)

from azureml.widgets import RunDetails
RunDetails(hyperdrive_run).show()
# Out:
# _HyperDriveWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO'…

# %%
import joblib
# Get your best run and save the model from that run.

best_run = hyperdrive_run.get_best_run_by_primary_metric()
best_run_metrics = best_run.get_metrics()
parameter_values = best_run.get_details()['runDefinition']['arguments']

print('Best Run Id: ', best_run.id)
print('\n Accuracy:', best_run_metrics['Accuracy'])
print('\n C:',parameter_values[1])
print('\n Max iterations:',parameter_values[3])

model = best_run.register_model(model_name = 'best_hyperdrive_model', model_path = 'outputs/model.joblib')
# Out:
# Best Run Id:  HD_6a8e5d11-2bca-486c-83ff-5aefda226f0e_4
#
#  Accuracy: 0.9150279193979121
#
#  C: 54.278853267640976
#
#  Max iterations: 100

# %%
from azureml.data.dataset_factory import TabularDatasetFactory

# Create TabularDataset using TabularDatasetFactory
# Data is available at: 
# "https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv"

data_path = "https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv"

ds = TabularDatasetFactory.from_delimited_files(path=data_path)

# %%
import sys  
sys.path.insert(0, './training')
from train import clean_data
from azureml.core.datastore import Datastore
import pandas

# Use the clean_data function to clean your data.
x = clean_data(ds)
x.head()
#data_store = Datastore(ws)
#x_ds = TabularDatasetFactory.register_pandas_dataframe(pandas.DataFrame(x), data_store, 'bankmarketing')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-636b84f87d1b> in <module>
#       7 # Use the clean_data function to clean your data.
#       8 x = clean_data(ds)
# ----> 9 x.head()
#      10 #data_store = Datastore(ws)
#      11 #x_ds = TabularDatasetFactory.register_pandas_dataframe(pandas.DataFrame(x), data_store, 'bankmarketing')
#
# AttributeError: 'tuple' object has no attribute 'head'

# %%
from azureml.train.automl import AutoMLConfig

# Set parameters for AutoMLConfig
# NOTE: DO NOT CHANGE THE experiment_timeout_minutes PARAMETER OR YOUR INSTANCE WILL TIME OUT.
# If you wish to run the experiment longer, you will need to run this notebook in your own
# Azure tenant, which will incur personal costs.
automl_config = AutoMLConfig(
    experiment_timeout_minutes=30,
    task="regression",
    primary_metric="spearman_correlation",
    training_data=x_ds,
    label_column_name="y",
    n_cross_validations=3)

# %%
# Submit your automl run

automl_run = exp.submit(automl_config)
# Out:
# WARNING - Running on local machine. Note that local runs always run synchronously even if you use the parameter 'show_output=False'
# ---------------------------------------------------------------------------
# DataflowValidationError                   Traceback (most recent call last)
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/automl/runtime/training_utilities.py in _extract_data_from_combined_dataflow(training_data, label_column_name, sample_weight_column_name, cv_split_column_names)
#    1890         y = training_data.keep_columns([label_column_name], validate_column_exists=True) \
# -> 1891             if label_column_name is not None else None
#    1892     except DataflowValidationError:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/dataprep/api/dataflow.py in keep_columns(self, columns, validate_column_exists)
#    2661         if validate_column_exists:
# -> 2662             df._verify_has_data_using_profile()
#    2663
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/dataprep/api/_loggerfactory.py in wrapper(*args, **kwargs)
#     199                 try:
# --> 200                     return func(*args, **kwargs)
#     201                 except Exception as e:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/dataprep/api/dataflow.py in _verify_has_data_using_profile(self)
#     884         if profile.row_count == 0 or profile.row_count is None:
# --> 885             raise DataflowValidationError("The Dataflow produced no records.")
#     886
#
# DataflowValidationError:
# Error Code: Empty
# Error Message: The Dataflow produced no records.| session_id=08fb245f-c5e5-435e-91b2-a4e7b9e6319c
#
# During handling of the above exception, another exception occurred:
#
# DataException                             Traceback (most recent call last)
# <ipython-input-41-368245887f48> in <module>
#       1 # Submit your automl run
#       2
# ----> 3 automl_run = exp.submit(automl_config)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/experiment.py in submit(self, config, tags, **kwargs)
#     217         submit_func = get_experiment_submit(config)
#     218         with self._log_context("submit config {}".format(config.__class__.__name__)):
# --> 219             run = submit_func(config, self.workspace, self.name, **kwargs)
#     220         if tags is not None:
#     221             run.set_tags(tags)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/train/automl/automlconfig.py in _automl_static_submit(automl_config_object, workspace, experiment_name, **kwargs)
#     104         compute_target,
#     105         parent_run_id,
# --> 106         show_output)
#     107
#     108     automl_run.add_properties(global_tracking_info_registry.gather_all(settings.path))
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/train/automl/automlconfig.py in _start_execution(experiment, settings_obj, fit_params, run_config, compute_target, parent_run_id, show_output)
#     261                 ignored_dependencies=package_utilities._PACKAGES_TO_IGNORE_VERSIONS
#     262             )
# --> 263         automl_run = _default_execution(experiment, settings_obj, fit_params, True, show_output, parent_run_id)
#     264     elif is_managed:
#     265         logger.info("Submitting local managed run.")
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/train/automl/automlconfig.py in _default_execution(experiment, settings_obj, fit_params, legacy_local, show_output, parent_run_id)
#     128     automl_estimator = _azureautomlclient.AzureAutoMLClient(experiment, settings_obj)
#     129
# --> 130     return automl_estimator.fit(**fit_params)
#     131
#     132
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/train/automl/_azureautomlclient.py in fit(self, run_configuration, compute_target, X, y, sample_weight, X_valid, y_valid, sample_weight_valid, cv_splits_indices, show_output, existing_run, training_data, validation_data, _script_run, parent_run_id, kwargs)
#     371                     existing_run=existing_run, sample_weight_valid=sample_weight_valid,
#     372                     training_data=training_data, validation_data=validation_data, _script_run=_script_run,
# --> 373                     parent_run_id=parent_run_id)
#     374             else:
#     375                 self._console_writer.println('Running on remote compute: ' + str(run_configuration.target))
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/train/automl/runtime/_runtime_client.py in _fit_local(self, X, y, sample_weight, X_valid, y_valid, sample_weight_valid, cv_splits_indices, existing_run, training_data, validation_data, _script_run, parent_run_id)
#     312             sample_weight_valid=sample_weight_valid,
#     313             training_data=training_data, validation_data=validation_data, verifier=verifier, _script_run=_script_run,
# --> 314             parent_run_id=parent_run_id)
#     315
#     316         cache_store = CacheStoreFactory.get_cache_store(
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/train/automl/runtime/_runtime_client.py in _create_parent_run_for_local(self, use_validation_service, X, y, sample_weight, X_valid, y_valid, sample_weight_valid, cv_splits_indices, existing_run, managed_run_id, training_data, validation_data, verifier, _script_run, parent_run_id)
#     135             automl_settings=self.azureautomlclient.automl_settings,
#     136             is_adb_run=True,
# --> 137             verifier=verifier)
#     138         training_utilities.set_task_parameters(y=self.azureautomlclient.input_data.get('y'),
#     139                                                automl_settings=self.azureautomlclient.automl_settings)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/automl/runtime/training_utilities.py in format_training_data(X, y, sample_weight, X_valid, y_valid, sample_weight_valid, cv_splits_indices, user_script, training_data, validation_data, label_column_name, weight_column_name, cv_split_column_names, is_adb_run, automl_settings, verifier)
#     241                 X, y, sample_weight, cv_splits_indices = _extract_data_from_combined_dataflow(
#     242                     training_data=training_data, label_column_name=label_column_name,
# --> 243                     sample_weight_column_name=weight_column_name, cv_split_column_names=cv_split_column_names
#     244                 )
#     245
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/automl/runtime/training_utilities.py in _extract_data_from_combined_dataflow(training_data, label_column_name, sample_weight_column_name, cv_split_column_names)
#    1894             MissingColumnsInData, target="label_column_name", data_object_name="X",
#    1895             columns="{} (label_column_name)".format(label_column_name),
# -> 1896             reference_code=ReferenceCodes._EXTRACT_DATA_FROM_COMBINED_DATAFLOW_LABEL_COLUMN_MISSING)
#    1897         )
#    1898     return X, y, sample_weight, cv_splits_indices
#
# DataException: DataException:
# 	Message: Expected column(s) y (label_column_name) not found in X.
# 	InnerException: None
# 	ErrorResponse
# {
#     "error": {
#         "code": "UserError",
#         "message": "Expected column(s) y (label_column_name) not found in X.",
#         "target": "label_column_name",
#         "inner_error": {
#             "code": "BadArgument",
#             "inner_error": {
#                 "code": "MissingColumnsInData"
#             }
#         },
#         "reference_code": "06328553-815b-486d-98dd-98e4c8952a7c"
#     }
# }

# %%
# Retrieve and save your best automl model.

### YOUR CODE HERE ###
